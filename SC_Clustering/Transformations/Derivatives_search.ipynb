# %%
import os
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('./contracts_source_codes.csv')

# %%
deriv_df = df[df.source_code.str.contains('derivativ|Derivativ')]
instr_df = df[df.source_code.str.contains('instruments|Instruments')]

# %%
deriv_df1 = df[df.code_all_no_punct.str.contains('future|Future')]
deriv_df2 = df[df.code_all_no_punct.str.contains('forward|Forward')]
deriv_df3 = df[df.code_all_no_punct.str.contains('option|Option')]
deriv_df4 = df[df.code_all_no_punct.str.contains('stock|Stock')]

# %% [markdown]
# 0x9a60e133d8382904563a7ce9490ef53f92ff4c01
# 0x9482a18ed523b1a2f097b480d38852dfff83e0b9
# 0x3f8a7f9ccd72f8b81c02c4cd3cfdfa30f1be5463
# 0x651aa5ea257af3d6fd08aedca8c5a446edb7b7a6

# %%
for i in deriv_df.address:
    # derivative and future
    print(i in deriv_df1.address)
    # derivative and forward
    print(i in deriv_df2.address)
    # derivative and option
    print(i in deriv_df3.address)
    # derivative and stock
    print(i in deriv_df4.address)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
with open("./derivative.json", 'r') as file:
    data = file.read()

# %%
import json
from pprint import pprint

with open('./derivative.json') as f:
    data = json.load(f)

# %%
deriv_df
# Out:
#                                           address       contract_name  \
# 1664   0xc7755ccdc4aea8948ceb1ed43edb92a73a323382                 NaN
# 2424   0x9a60e133d8382904563a7ce9490ef53f92ff4c01             Ownable
# 3318   0x9482a18ed523b1a2f097b480d38852dfff83e0b9                 NaN
# 4254   0x3f8a7f9ccd72f8b81c02c4cd3cfdfa30f1be5463          ERC20Basic
# 5025   0x651aa5ea257af3d6fd08aedca8c5a446edb7b7a6  TokenTransferProxy
# 6147   0xc479e26a7237c1839f44a09843699597ef23e2c3           OraclizeI
# 6631   0xeff0ea1b8718e8e5c11de028da40d6eeeb782432  TokenTransferProxy
# 7671   0x6ed680055bd5a04c194c954f71019ee90145001c      ERC20Interface
# 7672   0x6ed680055bd5a04c194c954f71019ee90145001c      ERC20Interface
# 8183   0x58f745e66fc8bb2307e8d73d7dafeda47030113c                 NaN
# 8592   0x3cf916f0ea2d75a8ccc3899d01f329f8b471127e          ERC20Basic
# 11001  0xe0b1bfe763b2cd43c652471bf126f5a577a81567       ERC20NoReturn
#
#                                              source_code  \
# 1664   pragma solidity ^0.4.24;\n\n\n\n//Swap Deploye...
# 2424   /*\n\n *  BAOXCOIN Cryptoshare Source Code\n\n...
# 3318   pragma solidity ^0.4.24;\n\n\n\n\n\n//Swap int...
# 4254   pragma solidity 0.4.24;\n\n\n\n/**\n\n * @titl...
# 5025   /*\n\n\n\n  Copyright 2018 Ethfinex Inc\n\n\n\...
# 6147   pragma solidity ^0.4.24;\n\n\n\n// File: oracl...
# 6631   /*\n\n\n\n  Copyright 2018 Ethfinex Inc\n\n\n\...
# 7671   pragma solidity ^0.4.24;\n\n// King of the Cry...
# 7672   pragma solidity ^0.4.24;\n\n// King of the Cry...
# 8183   pragma solidity ^0.4.24;\n\n\n\n//Swap Deploye...
# 8592   pragma solidity >0.4.23 <0.5.0;\n\nlibrary Saf...
# 11001  pragma solidity 0.4.24;\n\n\n\n/**\n\n * @titl...
#
#                                     contract_name_string  \
# 1664                    DRCT_Token Factory
# 2424   Ownable ERC20Basic BasicToken is ERC20Basic Bu...
# 3318     DRCT_Token Factory               Wrapped_Eth...
# 4254   ERC20Basic ERC20 is ERC20Basic ERC20Extended i...
# 5025    TokenTransferProxy SafeMath Exchange is SafeMath
# 6147       OraclizeI OraclizeAddrResolverI usingOraclize
# 6631                                     only_1_contract
# 7671   ERC20Interface  ApproveAndCallFallBack Owned F...
# 7672   ERC20Interface  ApproveAndCallFallBack Owned F...
# 8183       DRCT_Token Factory               CloneFactory
# 8592   ERC20Basic ERC20 is ERC20Basic BasicToken is E...
# 11001  ERC20NoReturn Ownable ERC20Basic ERC20 is ERC2...
#
#                                           function_names  \
# 1664   s  descriptions can be found in Deployersol ne...
# 2424   mul div sub add Ownable transferOwnership tota...
# 3318   createSwap s  descriptions can be found in Dep...
# 4254   totalSupply balanceOf transfer allowance trans...
# 5025   transfer transferFrom approve balanceOf allowa...
# 6147   query query_withGasLimit query2 query2_withGas...
# 6631   transfer transferFrom approve balanceOf allowa...
# 7671   add sub mul div totalSupply balanceOf allowanc...
# 7672   add sub mul div totalSupply balanceOf allowanc...
# 8183   s  descriptions can be found in Deployersol ne...
# 8592   mul div sub add totalSupply balanceOf transfer...
# 11001  mul div sub add totalSupply balanceOf allowanc...
#
#                                                 comments  \
# 1664   The DRCTLibrary contains the reference code us...
# 2424   BAOXCOIN Cryptoshare Source Code www localcoin...
# 3318   The DRCTLibrary contains the reference code us...
# 4254   title ERC20Basic dev Simpler version of ERC20 ...
# 5025   Copyright 2018 Ethfinex Inc This is a derivati...
# 6147   Copyright c 2015 2016 Oraclize SRLCopyright c ...
# 6631   Copyright 2018 Ethfinex Inc This is a derivati...
# 7671   King of the Crypto Hill contract by Spielley P...
# 7672   King of the Crypto Hill contract by Spielley P...
# 8183   The DRCTLibrary contains the reference code us...
# 8592   delete extra methods Struct Art Hash www dropb...
# 11001  title SafeMath dev Math operations with safety...
#
#                                        code_all_no_punct  timestamp  n_tr  \
# 1664   pragma solidity 0 4 24 Swap Deployer functions...  7/30/2018     1
# 2424   BAOXCOIN Cryptoshare Source Code www localcoin...   6/7/2018     3
# 3318   pragma solidity 0 4 24 Swap interface descript...  7/31/2018     5
# 4254   pragma solidity 0 4 24 title ERC20Basic dev Si...  7/13/2018    10
# 5025   Copyright 2018 Ethfinex Inc This is a derivati...  7/31/2018     1
# 6147   pragma solidity 0 4 24 File oraclize api using...   8/1/2018    18
# 6631   Copyright 2018 Ethfinex Inc This is a derivati...  7/31/2018     0
# 7671   pragma solidity 0 4 24 King of the Crypto Hill...  8/15/2018   765
# 7672   pragma solidity 0 4 24 King of the Crypto Hill...  8/15/2018   810
# 8183   pragma solidity 0 4 24 Swap Deployer functions...  7/31/2018     8
# 8592   pragma solidity 0 4 23 0 5 0 library SafeMath ...  6/27/2018     1
# 11001  pragma solidity 0 4 24 title SafeMath dev Math...   7/9/2018     5
#
#                              ether
# 1664                       0 Ether
# 2424                       0 Ether
# 3318                       0 Ether
# 4254    0.040958265909039057 Ether
# 5025                       0 Ether
# 6147     0.07181213979234035 Ether
# 6631                       0 Ether
# 7671    0.357391259140968536 Ether
# 7672    0.507657721271008157 Ether
# 8183                       0 Ether
# 8592                       0 Ether
# 11001                      0 Ether
